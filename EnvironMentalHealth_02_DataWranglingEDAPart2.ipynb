# %% [markdown]
# # Worldwide Environmental Health and Mental Health
#
# ## Part 2
# ## Further Data Wrangling & Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Micronutrient Status Data

# %%
#micronutrient status
df114 = pd.read_csv('WHO/VMNISIndicator_25-Hydroxyvitamin D_30102021.csv')
df115 = pd.read_csv('WHO/VMNISIndicator_Beta-carotene_30102021.csv')
df116 = pd.read_csv('WHO/VMNISIndicator_Calcium (plasma or serum)_30102021.csv')
df117 = pd.read_csv('WHO/VMNISIndicator_Copper (plasma or serum)_30102021.csv')
df118 = pd.read_csv('WHO/VMNISIndicator_Erythocyte glutamate-oxaloacetate transaminase (EGOT)_30102021.csv')
df119 = pd.read_csv('WHO/VMNISIndicator_Erythrocyte glutathione reductase activity coefficient (EGRAC)_30102021.csv')
df120 = pd.read_csv('WHO/VMNISIndicator_Erythrocyte transketolase activity coefficient (ETKAC)_30102021.csv')
df121 = pd.read_csv('WHO/VMNISIndicator_Ferritin_30102021.csv')
df122 = pd.read_csv('WHO/VMNISIndicator_Folate (plasma or serum)_30102021.csv')
df123 = pd.read_csv('WHO/VMNISIndicator_Folate (red blood cell)_30102021.csv')
df124 = pd.read_csv('WHO/VMNISIndicator_Goitre by ultrasound_30102021.csv')
df125 = pd.read_csv('WHO/VMNISIndicator_Haemoglobin_30102021.csv')
df126 = pd.read_csv('WHO/VMNISIndicator_Homocysteine_30102021.csv')
df127 = pd.read_csv('WHO/VMNISIndicator_Iodine_30102021.csv')
df128 = pd.read_csv('WHO/VMNISIndicator_Iron (serum or plasma)_30102021.csv')
df129 = pd.read_csv('WHO/VMNISIndicator_Iron deficiency anaemia_30102021.csv')
df130 = pd.read_csv('WHO/VMNISIndicator_Magnesium_30102021.csv')
df131 = pd.read_csv('WHO/VMNISIndicator_Mean corpuscular volume (MCV)_30102021.csv')
df132 = pd.read_csv('WHO/VMNISIndicator_Retinol binding protein_30102021.csv')
df133 = pd.read_csv('WHO/VMNISIndicator_Selenium (plama or serum)_30102021.csv')
df134 = pd.read_csv('WHO/VMNISIndicator_Thyroid stimulating hormone (TSH)_30102021.csv')
df135 = pd.read_csv('WHO/VMNISIndicator_Vitamin B12_30102021.csv')
df136 = pd.read_csv('WHO/VMNISIndicator_Vitamin C_30102021.csv')
df137 = pd.read_csv('WHO/VMNISIndicator_Vitamin E (alpha-tocopherol)_30102021.csv')
df138 = pd.read_csv('WHO/VMNISIndicator_Vitamin E (gamma-tocopherol)_30102021.csv')
df139 = pd.read_csv('WHO/VMNISIndicator_Xerophthalmia_30102021.csv')
df140 = pd.read_csv('WHO/VMNISIndicator_Zinc (plasma or serum)_30102021.csv')

# %% [markdown]
# ### Exploring Completeness of Available Micronutrient Status Data

# %%
df114.info()
df114.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                85 non-null     object
#  1   CountryCode               85 non-null     object
#  2   Country                   85 non-null     object
#  3   Representativeness.       85 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              85 non-null     object
#  6   Date                      85 non-null     int64
#  7   Begin month               79 non-null     float64
#  8   Begin year                85 non-null     int64
#  9   End month                 79 non-null     float64
#  10  End year                  85 non-null     int64
#  11  Population                85 non-null     object
#  12  Gender                    85 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df114.isnull().sum(), 100 * df114.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Link to reference 1           0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Season                        0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Method of analysis            0    0.000000
# Fasting                       0    0.000000
# Sample type                   0    0.000000
# Sample collection method      0    0.000000
# SurveyId                      0    0.000000
# Age from                      0    0.000000
# Survey status                 0    0.000000
# Gender                        0    0.000000
# CountryCode                   0    0.000000
# Country                       0    0.000000
# Representativeness.           0    0.000000
# Area covered                  0    0.000000
# Date                          0    0.000000
# ...

# %%
df114.Country.unique()
# Out:
# array(['Australia', 'Austria', 'Canada', 'China', 'Germany', 'France',
#        'United Kingdom of Great Britain and Northern', 'Ireland'],
#       dtype=object)

# %%
df114['Begin year'].unique()
# Out:
# array([2011, 2010, 2007, 2009, 1997, 2006, 1994, 2000, 2008])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Deficiency prevalence", "Mean", "Deficiency cut-off", "Median", "Insufficiency prevalence", "Insufficiency cut-off", "U95CI", "L95CI"]
df114=df114[labels]

# %%
df114.shape
df114.head(15)
# Out:
#              Indicator.    Country  Date   Population  Gender Indicator unit  \
# 0   25-Hydroxyvitamin D  Australia  2012  Adolescents     All         nmol/L
# 1   25-Hydroxyvitamin D  Australia  2012       Adults     All            NaN
# 2   25-Hydroxyvitamin D  Australia  2012       Adults     All            NaN
# 3   25-Hydroxyvitamin D  Australia  2012       Adults     All            NaN
# 4   25-Hydroxyvitamin D  Australia  2012       Adults     All            NaN
# 5   25-Hydroxyvitamin D  Australia  2012       Adults     All         nmol/L
# 6   25-Hydroxyvitamin D  Australia  2012       Adults     All         nmol/L
# 7   25-Hydroxyvitamin D  Australia  2012       Adults     All         nmol/L
# 8   25-Hydroxyvitamin D  Australia  2012       Adults     All         nmol/L
# 9   25-Hydroxyvitamin D  Australia  2012       Adults     All         nmol/L
# 10  25-Hydroxyvitamin D  Australia  2012       Adults     All         nmol/L
# ...

# %%
(df114["Country"] + ", " + df114["Population"]).value_counts()
# Out:
# Australia, Adults                                        11
# United Kingdom of Great Britain and Northern, Elderly     9
# Ireland, Adults                                           8
# Canada, Elderly                                           6
# China, Adolescents                                        6
# Canada, Adolescents                                       6
# United Kingdom of Great Britain and Northern, Men         5
# Canada, Adults                                            4
# Austria, Adolescents                                      4
# Austria, Men                                              4
# Canada, Men                                               4
# France, Men                                               3
# Austria, Women                                            2
# France, Women                                             2
# Austria, Elderly                                          2
# France, Adults                                            2
# ...

# %%
df114.Country.value_counts()
# Out:
# Canada                                          21
# Australia                                       15
# United Kingdom of Great Britain and Northern    14
# Austria                                         12
# Ireland                                          8
# France                                           7
# China                                            6
# Germany                                          2
# Name: Country, dtype: int64

# %%
df115.info()
df115.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                32 non-null     object
#  1   CountryCode               32 non-null     object
#  2   Country                   32 non-null     object
#  3   Representativeness.       32 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              32 non-null     object
#  6   Date                      32 non-null     int64
#  7   Begin month               32 non-null     int64
#  8   Begin year                32 non-null     int64
#  9   End month                 32 non-null     int64
#  10  End year                  32 non-null     int64
#  11  Population                32 non-null     object
#  12  Gender                    32 non-null     object
#  13  Age unit                  32 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df115.isnull().sum(), 100 * df115.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count        %
# Indicator.                    0    0.000
# Link to reference 1           0    0.000
# Reference 1                   0    0.000
# Reference no# 1               0    0.000
# Season                        0    0.000
# Survey methodology            0    0.000
# Indicator comments            0    0.000
# Method of analysis            0    0.000
# Fasting                       0    0.000
# Sample type                   0    0.000
# Sample collection method      0    0.000
# SurveyId                      0    0.000
# Indicator unit                0    0.000
# Age from                      0    0.000
# Survey status                 0    0.000
# CountryCode                   0    0.000
# Representativeness.           0    0.000
# Gender                        0    0.000
# Area covered                  0    0.000
# Date                          0    0.000
# Age unit                      0    0.000
# Begin month                   0    0.000
# ...

# %%
df115.Country.unique()
# Out:
# array(['Austria', 'France',
#        'United Kingdom of Great Britain and Northern'], dtype=object)

# %%
df115['Begin year'].unique()
# Out:
# array([2010, 1994, 2000])

# %% [markdown]
# This indicator is also available for very few countries and years.

# %%
df116.info()
df116.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                23 non-null     object
#  1   CountryCode               23 non-null     object
#  2   Country                   23 non-null     object
#  3   Representativeness.       23 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              23 non-null     object
#  6   Date                      23 non-null     int64
#  7   Begin month               23 non-null     int64
#  8   Begin year                23 non-null     int64
#  9   End month                 23 non-null     int64
#  10  End year                  23 non-null     int64
#  11  Population                23 non-null     object
#  12  Gender                    23 non-null     object
#  13  Age unit                  23 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df116.isnull().sum(), 100 * df116.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Reference 3                   0    0.000000
# Reference no# 3               0    0.000000
# Link to reference 2           0    0.000000
# Reference 2                   0    0.000000
# Reference no# 2               0    0.000000
# Link to reference 1           0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Method of analysis            0    0.000000
# Sample type                   0    0.000000
# Sample collection method      0    0.000000
# SurveyId                      0    0.000000
# Survey status                 0    0.000000
# Area covered                  0    0.000000
# Age to                        0    0.000000
# Population                    0    0.000000
# Gender                        0    0.000000
# ...

# %%
df116.Country.unique()
# Out:
# array(['Austria', 'Canada'], dtype=object)

# %%
df116['Begin year'].unique()
# Out:
# array([2010, 2009])

# %% [markdown]
# Also available for few countries and years so will not be used.

# %%
df117.info()
df117.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                20 non-null     object
#  1   CountryCode               20 non-null     object
#  2   Country                   20 non-null     object
#  3   Representativeness.       20 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              20 non-null     object
#  6   Date                      20 non-null     int64
#  7   Begin month               0 non-null      float64
#  8   Begin year                9 non-null      float64
#  9   End month                 0 non-null      float64
#  10  End year                  20 non-null     int64
#  11  Population                20 non-null     object
#  12  Gender                    20 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df117.isnull().sum(), 100 * df117.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count      %
# Indicator.                    0    0.0
# Link to reference 1           0    0.0
# Reference 1                   0    0.0
# Reference no# 1               0    0.0
# Season                        0    0.0
# Survey methodology            0    0.0
# Indicator comments            0    0.0
# Data adjusted for             0    0.0
# Method of analysis            0    0.0
# Fasting                       0    0.0
# Sample type                   0    0.0
# Sample collection method      0    0.0
# SurveyId                      0    0.0
# Indicator unit                0    0.0
# Sample size                   0    0.0
# Survey status                 0    0.0
# Age from                      0    0.0
# Date                          0    0.0
# Age to                        0    0.0
# Country                       0    0.0
# CountryCode                   0    0.0
# End year                      0    0.0
# Population                    0    0.0
# ...

# %%
df117.Country.unique()
# Out:
# array(['China', 'Kuwait'], dtype=object)

# %%
df117['Begin year'].unique()
# Out:
# array([2010.,   nan])

# %% [markdown]
# Due to lack of data, this indicator will not be used either.

# %%
df118.info()
df118.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 51 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Indicator.                      13 non-null     object
#  1   CountryCode                     13 non-null     object
#  2   Country                         13 non-null     object
#  3   Representativeness.             13 non-null     object
#  4   Representativeness name         0 non-null      float64
#  5   Area covered                    13 non-null     object
#  6   Date                            13 non-null     int64
#  7   Begin month                     13 non-null     int64
#  8   Begin year                      13 non-null     int64
#  9   End month                       13 non-null     int64
#  10  End year                        13 non-null     int64
#  11  Population                      13 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df118.isnull().sum(), 100 * df118.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                 count           %
# Indicator.                          0    0.000000
# Sample type                         0    0.000000
# Fasting                             0    0.000000
# Method of analysis                  0    0.000000
# Indicator comments                  0    0.000000
# Survey methodology                  0    0.000000
# Season                              0    0.000000
# Sample collection method            0    0.000000
# Reference no# 1                     0    0.000000
# Link to reference 1                 0    0.000000
# Reference no# 2                     0    0.000000
# Reference 2                         0    0.000000
# Link to reference 2                 0    0.000000
# Reference no# 3                     0    0.000000
# Reference 3                         0    0.000000
# Reference 1                         0    0.000000
# SurveyId                            0    0.000000
# Survey status                       0    0.000000
# ...

# %%
df118.Country.unique()
# Out:
# array(['Austria'], dtype=object)

# %% [markdown]
# This data is available for only one country so this indicator will not be used.

# %%
df119.info()
df119.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 51 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Indicator.                      27 non-null     object
#  1   CountryCode                     27 non-null     object
#  2   Country                         27 non-null     object
#  3   Representativeness.             27 non-null     object
#  4   Representativeness name         0 non-null      float64
#  5   Area covered                    27 non-null     object
#  6   Date                            27 non-null     int64
#  7   Begin month                     27 non-null     int64
#  8   Begin year                      27 non-null     int64
#  9   End month                       27 non-null     int64
#  10  End year                        27 non-null     int64
#  11  Population                      27 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df119.isnull().sum(), 100 * df119.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                 count           %
# Indicator.                          0    0.000000
# Link to reference 1                 0    0.000000
# Reference 1                         0    0.000000
# Reference no# 1                     0    0.000000
# Season                              0    0.000000
# Survey methodology                  0    0.000000
# Indicator comments                  0    0.000000
# Method of analysis                  0    0.000000
# Fasting                             0    0.000000
# Sample type                         0    0.000000
# Sample collection method            0    0.000000
# SurveyId                            0    0.000000
# Age from                            0    0.000000
# Survey status                       0    0.000000
# Gender                              0    0.000000
# CountryCode                         0    0.000000
# Country                             0    0.000000
# Representativeness.                 0    0.000000
# ...

# %%
df119.Country.unique()
# Out:
# array(['Austria', 'United Kingdom of Great Britain and Northern'],
#       dtype=object)

# %%
df119['Begin year'].unique()
# Out:
# array([2010, 1994, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df120.info()
df120.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 51 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Indicator.                      27 non-null     object
#  1   CountryCode                     27 non-null     object
#  2   Country                         27 non-null     object
#  3   Representativeness.             27 non-null     object
#  4   Representativeness name         0 non-null      float64
#  5   Area covered                    27 non-null     object
#  6   Date                            27 non-null     int64
#  7   Begin month                     27 non-null     int64
#  8   Begin year                      27 non-null     int64
#  9   End month                       27 non-null     int64
#  10  End year                        27 non-null     int64
#  11  Population                      27 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df120.isnull().sum(), 100 * df120.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                 count           %
# Indicator.                          0    0.000000
# Link to reference 1                 0    0.000000
# Reference 1                         0    0.000000
# Count of Reference no# 1            0    0.000000
# Season                              0    0.000000
# Survey methodology                  0    0.000000
# Indicator comments                  0    0.000000
# Method of analysis                  0    0.000000
# Fasting                             0    0.000000
# Sample type                         0    0.000000
# Sample collection method            0    0.000000
# SurveyId                            0    0.000000
# Age from                            0    0.000000
# Survey status                       0    0.000000
# Gender                              0    0.000000
# CountryCode                         0    0.000000
# Country                             0    0.000000
# Representativeness.                 0    0.000000
# ...

# %%
df120.Country.unique()
# Out:
# array(['Austria', 'United Kingdom of Great Britain and Northern'],
#       dtype=object)

# %%
df120['Begin year'].unique()
# Out:
# array([2010, 1994, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df121.info()
df121.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Indicator.                       149 non-null    object
#  1   CountryCode                      149 non-null    object
#  2   Country                          149 non-null    object
#  3   Representativeness.              149 non-null    object
#  4   Representativeness name          0 non-null      float64
#  5   Area covered                     149 non-null    object
#  6   Date                             149 non-null    int64
#  7   Begin month                      140 non-null    float64
#  8   Begin year                       149 non-null    int64
#  9   End month                        140 non-null    float64
#  10  End year                         149 non-null    int64
#  11  Population                       149 non-null    object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df121.isnull().sum(), 100 * df121.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                  count           %
# Indicator.                           0    0.000000
# Reference 1                          0    0.000000
# Reference no# 1                      0    0.000000
# Survey methodology                   0    0.000000
# Indicator comments                   0    0.000000
# Data adjusted for                    0    0.000000
# Method of analysis                   0    0.000000
# Sample type                          0    0.000000
# Sample collection method             0    0.000000
# 1st prev desc                        0    0.000000
# SurveyId                             0    0.000000
# Age unit                             0    0.000000
# Survey status                        0    0.000000
# Population                           0    0.000000
# CountryCode                          0    0.000000
# Country                              0    0.000000
# Representativeness.                  0    0.000000
# ...

# %%
df121.Country.unique()
# Out:
# array(['Australia', 'Austria', 'Bangladesh', 'Belize', 'Canada',
#        'Colombia', 'Costa Rica', 'Dominica', 'Ecuador', 'France',
#        'United Kingdom of Great Britain and Northern', 'Kenya', 'Morocco',
#        'Mexico', 'Mauritius', 'Malawi', 'Nepal', 'New Zealand',
#        'Saint Vincent and the Grenadines'], dtype=object)

# %%
df121['Begin year'].unique()
# Out:
# array([2011, 2010, 2009, 2008, 1996, 2012, 1994, 2006, 2000, 1999, 1995,
#        2015, 2016, 2002])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Mean", "Depleted iron stores cut-off", "Depleted iron stores prevalence", "Median", "U95CI", "L95CI"]
df121=df121[labels]

# %%
df121.shape
df121.head(15)
# Out:
#    Indicator.    Country  Date   Population  Gender Indicator unit   Mean  \
# 0    Ferritin  Australia  2012  Adolescents     All           µg/L   45.1
# 1    Ferritin  Australia  2012       Adults     All           µg/L  145.0
# 2    Ferritin  Australia  2012       Adults     All           µg/L   86.9
# 3    Ferritin  Australia  2012       Adults     All           µg/L  118.7
# 4    Ferritin  Australia  2012       Adults     All           µg/L  139.1
# 5    Ferritin  Australia  2012       Adults     All           µg/L  166.1
# 6    Ferritin  Australia  2012       Adults     All           µg/L  182.1
# 7    Ferritin  Australia  2012       Adults  Female           µg/L   86.9
# 8    Ferritin  Australia  2012      Elderly     All           µg/L  184.9
# 9    Ferritin  Australia  2012      Elderly     All           µg/L  157.4
# 10   Ferritin  Australia  2012          Men    Male           µg/L  204.5
# 11   Ferritin    Austria  2012  Adolescents  Female           µg/L   20.0
# ...

# %%
(df121["Country"] + ", " + df121["Population"]).value_counts()
# Out:
# Nepal, Adolescents                                       16
# Ecuador, Adolescents                                      9
# United Kingdom of Great Britain and Northern, Elderly     9
# Costa Rica, Men                                           8
# Mexico, Elderly                                           8
# Australia, Adults                                         7
# France, Men                                               7
# Ecuador, Men                                              6
# Canada, Elderly                                           5
# Malawi, Men                                               5
# United Kingdom of Great Britain and Northern, Men         5
# Canada, Men                                               4
# Kenya, Men                                                4
# Austria, Adolescents                                      4
# Austria, Men                                              4
# New Zealand, Men                                          4
# ...

# %%
df121.Country.value_counts()
# Out:
# Ecuador                                         16
# Nepal                                           16
# Canada                                          15
# United Kingdom of Great Britain and Northern    14
# France                                          14
# New Zealand                                     13
# Austria                                         12
# Australia                                       11
# Costa Rica                                       8
# Mexico                                           8
# Malawi                                           8
# Bangladesh                                       4
# Kenya                                            4
# Saint Vincent and the Grenadines                 1
# Belize                                           1
# Colombia                                         1
# Mauritius                                        1
# Dominica                                         1
# ...

# %%
df122.info()
df122.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                97 non-null     object
#  1   Country                   97 non-null     object
#  2   CountryCode               97 non-null     object
#  3   Representativeness.       97 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              97 non-null     object
#  6   Date                      97 non-null     int64
#  7   Begin month               97 non-null     int64
#  8   Begin year                97 non-null     int64
#  9   End month                 97 non-null     int64
#  10  End year                  97 non-null     int64
#  11  Population                97 non-null     object
#  12  Gender                    97 non-null     object
#  13  Age unit                  97 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df122.isnull().sum(), 100 * df122.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Method of analysis            0    0.000000
# Fasting                       0    0.000000
# Sample type                   0    0.000000
# Sample collection method      0    0.000000
# SurveyId                      0    0.000000
# Age from                      0    0.000000
# Age unit                      0    0.000000
# Survey status                 0    0.000000
# Population                    0    0.000000
# Country                       0    0.000000
# CountryCode                   0    0.000000
# Representativeness.           0    0.000000
# Gender                        0    0.000000
# Date                          0    0.000000
# Begin month                   0    0.000000
# ...

# %%
df122.Country.unique()
# Out:
# array(['Afghanistan', 'Chile', 'Costa Rica', 'Ecuador',
#        'United Kingdom of Great Britain and Northern', 'Austria',
#        'Ireland', 'France', 'Australia', 'New Zealand'], dtype=object)

# %%
df122['Begin year'].unique()
# Out:
# array([2013, 2009, 2008, 2012, 1994, 2010, 2000, 2006, 2011])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Deficiency prevalence", "Mean", "Deficiency cut-off", "Median", "U95CI", "L95CI"]
df122=df122[labels]

# %%
df122.shape
df122.head(15)
# Out:
#                   Indicator.      Country  Date   Population  Gender  \
# 0   Folate (plasma or serum)  Afghanistan  2013  Adolescents  Female
# 1   Folate (plasma or serum)        Chile  2010      Elderly     All
# 2   Folate (plasma or serum)        Chile  2010      Elderly  Female
# 3   Folate (plasma or serum)        Chile  2010      Elderly  Female
# 4   Folate (plasma or serum)        Chile  2010      Elderly  Female
# 5   Folate (plasma or serum)        Chile  2010      Elderly    Male
# 6   Folate (plasma or serum)        Chile  2010      Elderly    Male
# 7   Folate (plasma or serum)        Chile  2010      Elderly    Male
# 8   Folate (plasma or serum)   Costa Rica  2009      Elderly     All
# 9   Folate (plasma or serum)   Costa Rica  2009      Elderly  Female
# 10  Folate (plasma or serum)   Costa Rica  2009      Elderly    Male
# 11  Folate (plasma or serum)   Costa Rica  2009      Elderly     All
# 12  Folate (plasma or serum)   Costa Rica  2009      Elderly     All
# ...

# %%
(df122["Country"] + ", " + df122["Population"]).value_counts()
# Out:
# United Kingdom of Great Britain and Northern, Elderly    9
# Ireland, Adults                                          8
# Australia, Adults                                        7
# Chile, Elderly                                           7
# Ecuador, Adolescents                                     6
# Costa Rica, Elderly                                      6
# United Kingdom of Great Britain and Northern, Men        5
# Ecuador, Adults                                          5
# Austria, Men                                             4
# New Zealand, Men                                         4
# France, Adults                                           4
# Austria, Adolescents                                     4
# France, Men                                              3
# Ireland, Elderly                                         3
# Ecuador, Men                                             3
# New Zealand, Adolescents                                 3
# ...

# %%
df122.Country.value_counts()
# Out:
# Ecuador                                         15
# United Kingdom of Great Britain and Northern    14
# Austria                                         13
# New Zealand                                     12
# Ireland                                         11
# Australia                                       11
# France                                           7
# Chile                                            7
# Costa Rica                                       6
# Afghanistan                                      1
# Name: Country, dtype: int64

# %%
df123.info()
df123.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                61 non-null     object
#  1   CountryCode               61 non-null     object
#  2   Country                   61 non-null     object
#  3   Representativeness.       61 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              61 non-null     object
#  6   Date                      61 non-null     int64
#  7   Begin month               61 non-null     int64
#  8   Begin year                61 non-null     int64
#  9   End month                 61 non-null     int64
#  10  End year                  61 non-null     int64
#  11  Population                61 non-null     object
#  12  Gender                    61 non-null     object
#  13  Age unit                  61 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df123.isnull().sum(), 100 * df123.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Link to reference 1           0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Method of analysis            0    0.000000
# Fasting                       0    0.000000
# Sample type                   0    0.000000
# Sample collection method      0    0.000000
# SurveyId                      0    0.000000
# Sample size                   0    0.000000
# Age from                      0    0.000000
# Survey status                 0    0.000000
# Gender                        0    0.000000
# CountryCode                   0    0.000000
# Country                       0    0.000000
# Representativeness.           0    0.000000
# Area covered                  0    0.000000
# Date                          0    0.000000
# ...

# %%
df123.Country.unique()
# Out:
# array(['Australia', 'Ecuador',
#        'United Kingdom of Great Britain and Northern', 'Ireland', 'Nepal',
#        'New Zealand'], dtype=object)

# %%
df123['Begin year'].unique()
# Out:
# array([2011, 2012, 1994, 2000, 2008, 2016])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Deficiency prevalence", "Mean", "Deficiency cut-off", "Median", "Insufficiency prevalence", "Insufficiency cut-off", "U95CI", "L95CI"]
df123=df123[labels]

# %%
df123.shape
df123.head(15)
# Out:
#                  Indicator.    Country  Date   Population  Gender  \
# 0   Folate (red blood cell)  Australia  2012       Adults  Female
# 1   Folate (red blood cell)    Ecuador  2012  Adolescents     All
# 2   Folate (red blood cell)    Ecuador  2012  Adolescents     All
# 3   Folate (red blood cell)    Ecuador  2012  Adolescents  Female
# 4   Folate (red blood cell)    Ecuador  2012  Adolescents  Female
# 5   Folate (red blood cell)    Ecuador  2012  Adolescents    Male
# 6   Folate (red blood cell)    Ecuador  2012  Adolescents    Male
# 7   Folate (red blood cell)    Ecuador  2012       Adults     All
# 8   Folate (red blood cell)    Ecuador  2012       Adults     All
# 9   Folate (red blood cell)    Ecuador  2012       Adults     All
# 10  Folate (red blood cell)    Ecuador  2012       Adults     All
# 11  Folate (red blood cell)    Ecuador  2012          Men    Male
# 12  Folate (red blood cell)    Ecuador  2012          Men    Male
# ...

# %%
(df123["Country"] + ", " + df123["Population"]).value_counts()
# Out:
# United Kingdom of Great Britain and Northern, Elderly    9
# Ireland, Adults                                          8
# Nepal, Adolescents                                       8
# Ecuador, Adolescents                                     6
# United Kingdom of Great Britain and Northern, Men        5
# New Zealand, Men                                         4
# Ecuador, Men                                             4
# Ecuador, Adults                                          4
# New Zealand, Adolescents                                 3
# Ireland, Elderly                                         3
# New Zealand, Elderly                                     2
# New Zealand, Adults                                      2
# Ecuador, Women                                           1
# New Zealand, Women                                       1
# Australia, Adults                                        1
# dtype: int64

# %%
df123.Country.value_counts()
# Out:
# Ecuador                                         15
# United Kingdom of Great Britain and Northern    14
# New Zealand                                     12
# Ireland                                         11
# Nepal                                            8
# Australia                                        1
# Name: Country, dtype: int64

# %%
df124.info()
df124.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 47 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Indicator.                                                        6 non-null      object
#  1   CountryCode                                                       6 non-null      object
#  2   Country                                                           6 non-null      object
#  3   Representativeness.                                               6 non-null      object
#  4   Representativeness name                                           0 non-null      float64
#  5   Area covered                                                      6 non-null      object
#  6   Date                                                              6 non-null      int64
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df124.isnull().sum(), 100 * df124.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                                     count           %
# Indicator.                                              0    0.000000
# Reference 1                                             0    0.000000
# Reference no# 1                                         0    0.000000
# Old Reference no# 1                                     0    0.000000
# Season                                                  0    0.000000
# Survey methodology                                      0    0.000000
# Indicator comments                                      0    0.000000
# Data adjusted for                                       0    0.000000
# Method of analysis                                      0    0.000000
# SurveyId                                                0    0.000000
# Sample size                                             0    0.000000
# Age to                                                  0    0.000000
# ...

# %%
df124.Country.unique()
# Out:
# array(['France', 'Slovakia'], dtype=object)

# %%
df124['Begin year'].unique()
# Out:
# array([1994, 1988])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df125.info()
df125.head().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247 entries, 0 to 1246
# Data columns (total 53 columns):
#  #   Column                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                          --------------  -----
#  0   Applied filters:
# Micronutrient is Anaemia
# Representativeness is national
# Population Group is Adolescents, Adults, Men, Elderly, or Women
# Year is greater than or equal to 1990  1246 non-null   object
#  1   Unnamed: 1                                                                                                                                                                      1246 non-null   object
# ...

# %%
df125.head()
# Out:
#   Applied filters:\nMicronutrient is Anaemia\nRepresentativeness is national\nPopulation Group is Adolescents, Adults, Men, Elderly, or Women\nYear is greater than or equal to 1990  \
# 0                                                NaN
# 1                                         Indicator.
# 2                                        Haemoglobin
# 3                                        Haemoglobin
# 4                                        Haemoglobin
#
#     Unnamed: 1   Unnamed: 2           Unnamed: 3               Unnamed: 4  \
# 0          NaN          NaN                  NaN                      NaN
# 1  CountryCode      Country  Representativeness.  Representativeness name
# 2          AFG  Afghanistan             national                      NaN
# 3          AFG  Afghanistan             national                      NaN
# 4          AFG  Afghanistan             national                      NaN
#
# ...

# %%
df125.drop(labels=[0], axis=0, inplace=True)
df125.head()
# Out:
#   Applied filters:\nMicronutrient is Anaemia\nRepresentativeness is national\nPopulation Group is Adolescents, Adults, Men, Elderly, or Women\nYear is greater than or equal to 1990  \
# 1                                         Indicator.
# 2                                        Haemoglobin
# 3                                        Haemoglobin
# 4                                        Haemoglobin
# 5                                        Haemoglobin
#
#     Unnamed: 1   Unnamed: 2           Unnamed: 3               Unnamed: 4  \
# 1  CountryCode      Country  Representativeness.  Representativeness name
# 2          AFG  Afghanistan             national                      NaN
# 3          AFG  Afghanistan             national                      NaN
# 4          AFG  Afghanistan             national                      NaN
# 5          AFG  Afghanistan             national                      NaN
#
# ...

# %%
df125.columns = df125.iloc[0]
df125 = df125[1:]
df125.head()
# Out:
# 1   Indicator. CountryCode      Country Representativeness.  \
# 2  Haemoglobin         AFG  Afghanistan            national
# 3  Haemoglobin         AFG  Afghanistan            national
# 4  Haemoglobin         AFG  Afghanistan            national
# 5  Haemoglobin         AFG  Afghanistan            national
# 6  Haemoglobin         AFG  Afghanistan            national
#
# 1 Representativeness name          Area covered  Date Begin month Begin year  \
# 2                     NaN  both urban and rural  2004           5       2004
# 3                     NaN  both urban and rural  2004           5       2004
# 4                     NaN  both urban and rural  2004           5       2004
# 5                     NaN  both urban and rural  2004           5       2004
# 6                     NaN  both urban and rural  2004           5       2004
#
# 1 End month  ... Old Reference no# 2 Reference no# 2 Reference 2  \
# 2         6  ...                 NaN             NaN         NaN
# ...

# %%
df125.reset_index(inplace=True)
df125.head()
# Out:
# 1  index   Indicator. CountryCode      Country Representativeness.  \
# 0      2  Haemoglobin         AFG  Afghanistan            national
# 1      3  Haemoglobin         AFG  Afghanistan            national
# 2      4  Haemoglobin         AFG  Afghanistan            national
# 3      5  Haemoglobin         AFG  Afghanistan            national
# 4      6  Haemoglobin         AFG  Afghanistan            national
#
# 1 Representativeness name          Area covered  Date Begin month Begin year  \
# 0                     NaN  both urban and rural  2004           5       2004
# 1                     NaN  both urban and rural  2004           5       2004
# 2                     NaN  both urban and rural  2004           5       2004
# 3                     NaN  both urban and rural  2004           5       2004
# 4                     NaN  both urban and rural  2004           5       2004
#
# 1  ... Old Reference no# 2 Reference no# 2 Reference 2 Link to reference 2  \
# ...

# %%
df125.drop(labels='index', axis=1, inplace=True)
df125.head()
# Out:
# 1   Indicator. CountryCode      Country Representativeness.  \
# 0  Haemoglobin         AFG  Afghanistan            national
# 1  Haemoglobin         AFG  Afghanistan            national
# 2  Haemoglobin         AFG  Afghanistan            national
# 3  Haemoglobin         AFG  Afghanistan            national
# 4  Haemoglobin         AFG  Afghanistan            national
#
# 1 Representativeness name          Area covered  Date Begin month Begin year  \
# 0                     NaN  both urban and rural  2004           5       2004
# 1                     NaN  both urban and rural  2004           5       2004
# 2                     NaN  both urban and rural  2004           5       2004
# 3                     NaN  both urban and rural  2004           5       2004
# 4                     NaN  both urban and rural  2004           5       2004
#
# 1 End month  ... Old Reference no# 2 Reference no# 2 Reference 2  \
# 0         6  ...                 NaN             NaN         NaN
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df125.isnull().sum(), 100 * df125.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                              count           %
# 1
# Indicator.                       0    0.000000
# Reference 1                      0    0.000000
# Reference no# 1                  0    0.000000
# Data adjusted for                0    0.000000
# Method of analysis               0    0.000000
# Sample collection method         0    0.000000
# SurveyId                         0    0.000000
# Age unit                         0    0.000000
# Gender                           0    0.000000
# Population                       0    0.000000
# Survey status                    0    0.000000
# CountryCode                      0    0.000000
# Country                          0    0.000000
# Representativeness.              0    0.000000
# Area covered                     0    0.000000
# End year                         0    0.000000
# Date                             0    0.000000
# Indicator comments               1    0.080321
# Begin year                       5    0.401606
# ...

# %%
df125.Country.unique()
# Out:
# array(['Afghanistan', 'Albania.', 'Armenia', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bahrain', 'Belize', 'Bolivia (Plurinational State of)', 'Brazil',
#        'Brunei Darussalam', 'Bhutan', 'Central African Republic',
#        'Canada', 'Chile', 'China', "Côte d'Ivoire", 'Cameroon',
#        'Democratic Republic of the Congo', 'Congo', 'Colombia',
#        'Cabo Verde', 'Costa Rica', 'Dominica', 'Dominican Republic',
#        'Ecuador', 'Egypt', 'Ethiopia', 'Fiji', 'France', 'Gabon',
#        'United Kingdom of Great Britain and Northern', 'Guinea',
#        'Equatorial Guinea', 'Guyana', 'Haiti', 'Indonesia', 'India',
#        'Japan', 'Kenya', 'Kuwait', "Lao People's Democratic Republic",
#        'Sri Lanka', 'Lesotho', 'Morocco', 'Republic of Moldova',
#        'Madagascar', 'Maldives', 'Mexico', 'Mali', 'Myanmar', 'Mauritius',
#        'Malawi', 'Namibia', 'Niger', 'Nepal', 'New Zealand', 'Oman',
# ...

# %%
df125['Begin year'].unique()
# Out:
# array(['2004', '2013', '2008', '2000', '2005', '2015', '2011', '2010',
#        '1996', '2006', '2003', '2016', '2001', '1997', '1998', '2002',
#        '2009', '1992', '1995', '2007', '1993', '2012', '2014', '1994',
#        '1999', nan, '2017'], dtype=object)

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Anaemia prevalence", "Mean", "Anaemia cut-off", "Median", "U95CI", "L95CI"]
df125=df125[labels]

# %%
df125.shape
df125.head(15)
# Out:
# 1    Indicator.      Country  Date   Population  Gender Indicator unit  \
# 0   Haemoglobin  Afghanistan  2004  Adolescents  Female            g/L
# 1   Haemoglobin  Afghanistan  2004  Adolescents    Male            g/L
# 2   Haemoglobin  Afghanistan  2004          Men    Male            g/L
# 3   Haemoglobin  Afghanistan  2004          Men    Male            g/L
# 4   Haemoglobin  Afghanistan  2004          Men    Male            g/L
# 5   Haemoglobin  Afghanistan  2004          Men    Male            g/L
# 6   Haemoglobin  Afghanistan  2004          Men    Male            g/L
# 7   Haemoglobin  Afghanistan  2013  Adolescents  Female            g/L
# 8   Haemoglobin     Albania.  2009  Adolescents  Female            NaN
# 9   Haemoglobin     Albania.  2009  Adolescents    Male            NaN
# 10  Haemoglobin     Albania.  2009          Men    Male            NaN
# 11  Haemoglobin     Albania.  2009          Men    Male            NaN
# ...

# %%
(df125["Country"] + ", " + df125["Population"]).value_counts()
# Out:
# China, Adolescents          86
# Kuwait, Adolescents         36
# Bangladesh, Adolescents     35
# Uganda, Men                 28
# Egypt, Adolescents          27
#                             ..
# Cameroon, Adolescents        1
# Zambia, Men                  1
# Egypt, Men                   1
# Dominica, Adolescents        1
# Brunei Darussalam, Women     1
# Length: 159, dtype: int64

# %%
df125.Country.value_counts()
# Out:
# China                               121
# Thailand                             80
# Japan                                71
# Kuwait                               36
# Bangladesh                           35
#                                    ...
# Republic of Moldova                   1
# Brazil                                1
# Mauritius                             1
# Bolivia (Plurinational State of)      1
# Tajikistan                            1
# Name: Country, Length: 81, dtype: int64

# %%
df126.info()
df126.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 51 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Indicator.                         54 non-null     object
#  1   CountryCode                        54 non-null     object
#  2   Country                            54 non-null     object
#  3   Representativeness.                54 non-null     object
#  4   Representativeness name            0 non-null      float64
#  5   Area covered                       54 non-null     object
#  6   Date                               54 non-null     int64
#  7   Begin month                        54 non-null     int64
#  8   Begin year                         54 non-null     int64
#  9   End month                          54 non-null     int64
#  10  End year                           54 non-null     int64
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df126.isnull().sum(), 100 * df126.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                    count           %
# Indicator.                             0    0.000000
# Reference 1                            0    0.000000
# Reference no# 1                        0    0.000000
# Season                                 0    0.000000
# Survey methodology                     0    0.000000
# Indicator comments                     0    0.000000
# Data adjusted for                      0    0.000000
# Method of analysis                     0    0.000000
# Fasting                                0    0.000000
# Sample type                            0    0.000000
# SurveyId                               0    0.000000
# Age unit                               0    0.000000
# Survey status                          0    0.000000
# Population                             0    0.000000
# CountryCode                            0    0.000000
# Country                                0    0.000000
# Representativeness.                    0    0.000000
# ...

# %%
df126.Country.unique()
# Out:
# array(['Austria', 'Canada', 'Ireland', 'Costa Rica',
#        'United Kingdom of Great Britain and Northern'], dtype=object)

# %%
df126['Begin year'].unique()
# Out:
# array([2010, 2007, 2008, 2000])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Elevated threshold", "Prevalence of elevated Hcy", "Mean", "Median", "U95CI", "L95CI"]
df126=df126[labels]

# %%
df126.shape
df126.head(15)
# Out:
#       Indicator.  Country  Date   Population  Gender Elevated threshold  \
# 0   Homocysteine  Austria  2012  Adolescents  Female                NaN
# 1   Homocysteine  Austria  2012  Adolescents  Female                NaN
# 2   Homocysteine  Austria  2012  Adolescents    Male                NaN
# 3   Homocysteine  Austria  2012  Adolescents    Male                NaN
# 4   Homocysteine   Canada  2009  Adolescents     All                NaN
# 5   Homocysteine   Canada  2009  Adolescents  Female         >13 µmol/L
# 6   Homocysteine   Canada  2009  Adolescents    Male                NaN
# 7   Homocysteine   Canada  2009       Adults     All         >13 µmol/L
# 8   Homocysteine   Canada  2009       Adults     All         >13 µmol/L
# 9   Homocysteine  Ireland  2010       Adults     All                NaN
# 10  Homocysteine  Ireland  2010       Adults     All                NaN
# 11  Homocysteine  Ireland  2010       Adults     All                NaN
# ...

# %%
(df126["Country"] + ", " + df126["Population"]).value_counts()
# Out:
# Ireland, Adults                                      8
# Costa Rica, Elderly                                  6
# United Kingdom of Great Britain and Northern, Men    5
# Costa Rica, Women                                    4
# Austria, Adolescents                                 4
# Austria, Men                                         4
# Costa Rica, Men                                      4
# Austria, Elderly                                     3
# Canada, Adolescents                                  3
# Canada, Elderly                                      3
# Ireland, Elderly                                     3
# Austria, Women                                       2
# Canada, Adults                                       2
# Canada, Men                                          2
# Canada, Women                                        1
# dtype: int64

# %%
df126.Country.value_counts()
# Out:
# Costa Rica                                      14
# Austria                                         13
# Canada                                          11
# Ireland                                         11
# United Kingdom of Great Britain and Northern     5
# Name: Country, dtype: int64

# %%
df127.info()
df127.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                106 non-null    object
#  1   CountryCode               106 non-null    object
#  2   Country                   106 non-null    object
#  3   Representativeness.       106 non-null    object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              106 non-null    object
#  6   Date                      106 non-null    int64
#  7   Begin month               95 non-null     float64
#  8   Begin year                106 non-null    int64
#  9   End month                 95 non-null     float64
#  10  End year                  106 non-null    int64
#  11  Population                106 non-null    object
#  12  Gender                    106 non-null    object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df127.isnull().sum(), 100 * df127.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Data adjusted for             0    0.000000
# Method of analysis            0    0.000000
# Sample collection method      0    0.000000
# Fasting                       0    0.000000
# Sample type                   0    0.000000
# SurveyId                      0    0.000000
# Age from                      0    0.000000
# Age unit                      0    0.000000
# Survey status                 0    0.000000
# Population                    0    0.000000
# Representativeness.           0    0.000000
# Gender                        0    0.000000
# Area covered                  0    0.000000
# Date                          0    0.000000
# Begin year                    0    0.000000
# ...

# %%
df127['Sample type'].head()
# Out:
# 0    Urine sample - spot
# 1    Urine sample - spot
# 2    Urine sample - spot
# 3    Urine sample - spot
# 4    Urine sample - spot
# Name: Sample type, dtype: object

# %%
df127.Country.unique()
# Out:
# array(['Belgium', 'Malawi', 'Australia', 'Austria', 'Canada',
#        'United Kingdom of Great Britain and Northern', 'Ireland',
#        'New Zealand', 'Philippines', 'United Republic of Tanzania',
#        'Slovenia', 'Germany', 'Mauritius', 'France', 'Bangladesh', 'Chad'],
#       dtype=object)

# %%
df127['Begin year'].unique()
# Out:
# array([2018, 2015, 2011, 2010, 2009, 2008, 2004, 2003, 2002, 1996, 1995,
#        1994, 1993])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Mean", "Median", "U95CI", "L95CI"]
df127=df127[labels]

# %%
df127.shape
df127.head(15)
# Out:
#    Indicator.    Country  Date   Population  Gender Indicator unit  Mean  \
# 0      Iodine    Belgium  2018       Adults     All           µg/L   NaN
# 1      Iodine    Belgium  2018       Adults     All           µg/L   NaN
# 2      Iodine    Belgium  2018       Adults     All           µg/L   NaN
# 3      Iodine    Belgium  2018      Elderly     All           µg/L   NaN
# 4      Iodine    Belgium  2018          Men    Male           µg/L   NaN
# 5      Iodine    Belgium  2018        Women  Female           µg/L   NaN
# 6      Iodine     Malawi  2016  Adolescents     All           µg/L   NaN
# 7      Iodine  Australia  2012  Adolescents     All           µg/L   NaN
# 8      Iodine  Australia  2012       Adults     All           µg/L   NaN
# 9      Iodine  Australia  2012       Adults     All           µg/L   NaN
# 10     Iodine  Australia  2012       Adults     All           µg/L   NaN
# 11     Iodine  Australia  2012       Adults     All           µg/L   NaN
# ...

# %%
(df127["Country"] + ", " + df127["Population"]).value_counts()
# Out:
# Austria, Men                                                 8
# Austria, Adolescents                                         8
# Australia, Adults                                            7
# Austria, Elderly                                             4
# Austria, Women                                               4
# France, Women                                                4
# Ireland, Adults                                              4
# New Zealand, Adolescents                                     4
# New Zealand, Men                                             4
# France, Men                                                  4
# Ireland, Men                                                 4
# Mauritius, Adults                                            3
# Belgium, Adults                                              3
# Ireland, Elderly                                             3
# Canada, Elderly                                              3
# ...

# %%
df127.Country.value_counts()
# Out:
# Austria                                         24
# Ireland                                         13
# New Zealand                                     13
# Canada                                          11
# Australia                                       11
# France                                           8
# Belgium                                          6
# United Republic of Tanzania                      3
# Philippines                                      3
# Germany                                          3
# Mauritius                                        3
# Slovenia                                         3
# Bangladesh                                       2
# Malawi                                           1
# Chad                                             1
# United Kingdom of Great Britain and Northern     1
# Name: Country, dtype: int64

# %%
df128.info()
df128.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Indicator.                   26 non-null     object
#  1   CountryCode                  26 non-null     object
#  2   Country                      26 non-null     object
#  3   Representativeness.          26 non-null     object
#  4   Representativeness name      0 non-null      float64
#  5   Area covered                 26 non-null     object
#  6   Date                         26 non-null     int64
#  7   Begin month                  26 non-null     int64
#  8   Begin year                   26 non-null     int64
#  9   End month                    26 non-null     int64
#  10  End year                     26 non-null     int64
#  11  Population                   26 non-null     object
#  12  Gender                       26 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df128.isnull().sum(), 100 * df128.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                              count           %
# Indicator.                       0    0.000000
# Link to reference 1              0    0.000000
# Reference 1                      0    0.000000
# Reference no# 1                  0    0.000000
# Season                           0    0.000000
# Survey methodology               0    0.000000
# Indicator comments               0    0.000000
# Method of analysis               0    0.000000
# Fasting                          0    0.000000
# Sample type                      0    0.000000
# SurveyId                         0    0.000000
# Age from                         0    0.000000
# Age unit                         0    0.000000
# Survey status                    0    0.000000
# Population                       0    0.000000
# CountryCode                      0    0.000000
# Country                          0    0.000000
# Representativeness.              0    0.000000
# Area covered                     0    0.000000
# ...

# %%
df128.Country.unique()
# Out:
# array(['Austria', 'United Kingdom of Great Britain and Northern'],
#       dtype=object)

# %%
df128['Begin year'].unique()
# Out:
# array([2010, 1994, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df129.info()
df129.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                78 non-null     object
#  1   CountryCode               78 non-null     object
#  2   Country                   78 non-null     object
#  3   Representativeness.       78 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              78 non-null     object
#  6   Date                      78 non-null     int64
#  7   Begin month               70 non-null     float64
#  8   Begin year                77 non-null     float64
#  9   End month                 70 non-null     float64
#  10  End year                  78 non-null     int64
#  11  Population                78 non-null     object
#  12  Gender                    78 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df129.isnull().sum(), 100 * df129.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Season                        0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Data adjusted for             0    0.000000
# Method of analysis            0    0.000000
# Fasting                       0    0.000000
# SurveyId                      0    0.000000
# Sample collection method      0    0.000000
# IDA Prevalence                0    0.000000
# Age unit                      0    0.000000
# Sample type                   0    0.000000
# Representativeness.           0    0.000000
# CountryCode                   0    0.000000
# Country                       0    0.000000
# Gender                        0    0.000000
# Area covered                  0    0.000000
# Date                          0    0.000000
# ...

# %%
df129.Country.unique()
# Out:
# array(['Bangladesh', 'Canada', 'Ecuador', 'France', 'Kenya', 'Kuwait',
#        'Mexico', 'Mauritius', 'Malawi', 'Nepal', 'New Zealand'],
#       dtype=object)

# %%
df129['Begin year'].unique()
# Out:
# array([2011., 2009., 2012., 1994., 2006.,   nan, 1995., 2001., 2015.,
#        2016., 2002., 2008.])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "IDA Prevalence", "IDA cut-off"]
df129=df129[labels]

# %%
df129.shape
df129.head(15)
# Out:
#                  Indicator.     Country  Date   Population  Gender  \
# 0   Iron deficiency anaemia  Bangladesh  2011  Adolescents     All
# 1   Iron deficiency anaemia  Bangladesh  2011  Adolescents     All
# 2   Iron deficiency anaemia  Bangladesh  2011  Adolescents     All
# 3   Iron deficiency anaemia  Bangladesh  2011  Adolescents     All
# 4   Iron deficiency anaemia      Canada  2011  Adolescents  Female
# 5   Iron deficiency anaemia     Ecuador  2012  Adolescents  Female
# 6   Iron deficiency anaemia     Ecuador  2012  Adolescents  Female
# 7   Iron deficiency anaemia     Ecuador  2012  Adolescents  Female
# 8   Iron deficiency anaemia     Ecuador  2012       Adults  Female
# 9   Iron deficiency anaemia      France  1995          Men    Male
# 10  Iron deficiency anaemia      France  1995        Women  Female
# 11  Iron deficiency anaemia      France  2007       Adults     All
# 12  Iron deficiency anaemia      France  2007       Adults  Female
# ...

# %%
(df129["Country"] + ", " + df129["Population"]).value_counts()
# Out:
# Malawi, Men                 21
# Nepal, Adolescents          16
# Mexico, Elderly              6
# New Zealand, Men             4
# New Zealand, Adolescents     4
# Bangladesh, Adolescents      4
# Kenya, Men                   3
# France, Adults               3
# Ecuador, Adolescents         3
# Malawi, Adolescents          3
# New Zealand, Adults          2
# New Zealand, Elderly         2
# Mauritius, Men               1
# Kuwait, Adolescents          1
# New Zealand, Women           1
# France, Men                  1
# France, Women                1
# Canada, Adolescents          1
# Ecuador, Adults              1
# dtype: int64

# %%
df129.Country.value_counts()
# Out:
# Malawi         24
# Nepal          16
# New Zealand    13
# Mexico          6
# France          5
# Bangladesh      4
# Ecuador         4
# Kenya           3
# Canada          1
# Mauritius       1
# Kuwait          1
# Name: Country, dtype: int64

# %%
df130.info()
df130.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Indicator.                   13 non-null     object
#  1   CountryCode                  13 non-null     object
#  2   Country                      13 non-null     object
#  3   Representativeness.          13 non-null     object
#  4   Representativeness name      0 non-null      float64
#  5   Area covered                 13 non-null     object
#  6   Date                         13 non-null     int64
#  7   Begin month                  13 non-null     int64
#  8   Begin year                   13 non-null     int64
#  9   End month                    13 non-null     int64
#  10  End year                     13 non-null     int64
#  11  Population                   13 non-null     object
#  12  Gender                       13 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df130.isnull().sum(), 100 * df130.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                              count           %
# Indicator.                       0    0.000000
# Reference 3                      0    0.000000
# Reference no# 3                  0    0.000000
# Link to reference 2              0    0.000000
# Reference 2                      0    0.000000
# Reference no# 2                  0    0.000000
# Link to reference 1              0    0.000000
# Reference 1                      0    0.000000
# Reference no# 1                  0    0.000000
# Season                           0    0.000000
# Survey methodology               0    0.000000
# Indicator comments               0    0.000000
# Method of analysis               0    0.000000
# Fasting                          0    0.000000
# Sample type                      0    0.000000
# SurveyId                         0    0.000000
# Survey status                    0    0.000000
# Population                       0    0.000000
# CountryCode                      0    0.000000
# ...

# %%
df130.Country.unique()
# Out:
# array(['Austria'], dtype=object)

# %%
df130['Begin year'].unique()
# Out:
# array([2010])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df131.info()
df131.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Indicator.                        42 non-null     object
#  1   CountryCode                       42 non-null     object
#  2   Country                           42 non-null     object
#  3   Representativeness.               42 non-null     object
#  4   Representativeness name           0 non-null      float64
#  5   Area covered                      42 non-null     object
#  6   Date                              42 non-null     int64
#  7   Begin month                       42 non-null     int64
#  8   Begin year                        42 non-null     int64
#  9   End month                         42 non-null     int64
#  10  End year                          42 non-null     int64
#  11  Population                        42 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df131.isnull().sum(), 100 * df131.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                   count           %
# Indicator.                            0    0.000000
# Link to reference 1                   0    0.000000
# Reference 1                           0    0.000000
# Reference no# 1                       0    0.000000
# Season                                0    0.000000
# Survey methodology                    0    0.000000
# Indicator comments                    0    0.000000
# Method of analysis                    0    0.000000
# Fasting                               0    0.000000
# Sample type                           0    0.000000
# SurveyId                              0    0.000000
# Age from                              0    0.000000
# Age unit                              0    0.000000
# Survey status                         0    0.000000
# Population                            0    0.000000
# CountryCode                           0    0.000000
# Country                               0    0.000000
# ...

# %%
df131.Country.unique()
# Out:
# array(['Austria', 'Canada', 'Ecuador',
#        'United Kingdom of Great Britain and Northern'], dtype=object)

# %%
df131['Begin year'].unique()
# Out:
# array([2010, 2009, 2012, 1994, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df132.info()
df132.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 49 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator.               23 non-null     object
#  1   CountryCode              23 non-null     object
#  2   Country                  23 non-null     object
#  3   Representativeness.      23 non-null     object
#  4   Representativeness name  0 non-null      float64
#  5   Area covered             23 non-null     object
#  6   Date                     23 non-null     int64
#  7   Begin month              23 non-null     int64
#  8   Begin year               23 non-null     int64
#  9   End month                23 non-null     int64
#  10  End year                 23 non-null     int64
#  11  Population               23 non-null     object
#  12  Gender                   23 non-null     object
#  13  Age unit                 23 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df132.isnull().sum(), 100 * df132.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                          count           %
# Indicator.                   0    0.000000
# Reference 1                  0    0.000000
# Reference no# 1              0    0.000000
# Season                       0    0.000000
# Survey methodology           0    0.000000
# Indicator comments           0    0.000000
# Data adjusted for            0    0.000000
# Method of analysis           0    0.000000
# Fasting                      0    0.000000
# Sample type                  0    0.000000
# SurveyId                     0    0.000000
# Sample size                  0    0.000000
# Age to                       0    0.000000
# Age from                     0    0.000000
# Survey status                0    0.000000
# Gender                       0    0.000000
# Population                   0    0.000000
# CountryCode                  0    0.000000
# Country                      0    0.000000
# Representativeness.          0    0.000000
# Area covered                 0    0.000000
# ...

# %%
df132.Country.unique()
# Out:
# array(['Austria', 'Kenya', 'Malawi', 'Nepal'], dtype=object)

# %%
df132['Begin year'].unique()
# Out:
# array([2010, 2011, 2009, 2015, 2016])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df133.info()
df133.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Indicator.                     21 non-null     object
#  1   CountryCode                    21 non-null     object
#  2   Country                        21 non-null     object
#  3   Representativeness.            21 non-null     object
#  4   Representativeness name        0 non-null      float64
#  5   Area covered                   21 non-null     object
#  6   Date                           21 non-null     int64
#  7   Begin month                    21 non-null     int64
#  8   Begin year                     21 non-null     int64
#  9   End month                      21 non-null     int64
#  10  End year                       21 non-null     int64
#  11  Population                     21 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df133.isnull().sum(), 100 * df133.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                count           %
# Indicator.                         0    0.000000
# Reference 1                        0    0.000000
# Reference no# 1                    0    0.000000
# Season                             0    0.000000
# Survey methodology                 0    0.000000
# Indicator comments                 0    0.000000
# Method of analysis                 0    0.000000
# Fasting                            0    0.000000
# Sample type                        0    0.000000
# SurveyId                           0    0.000000
# Age to                             0    0.000000
# Age from                           0    0.000000
# Age unit                           0    0.000000
# Survey status                      0    0.000000
# Population                         0    0.000000
# CountryCode                        0    0.000000
# Country                            0    0.000000
# Representativeness.                0    0.000000
# ...

# %%
df133.Country.unique()
# Out:
# array(['Austria', 'Costa Rica',
#        'United Kingdom of Great Britain and Northern'], dtype=object)

# %%
df133['Begin year'].unique()
# Out:
# array([2010, 2008, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df134.info()
df134.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Indicator.                          17 non-null     object
#  1   CountryCode                         17 non-null     object
#  2   Country                             17 non-null     object
#  3   Representativeness.                 17 non-null     object
#  4   Representativeness name             0 non-null      float64
#  5   Area covered                        17 non-null     object
#  6   Date                                17 non-null     int64
#  7   Begin month                         17 non-null     int64
#  8   Begin year                          17 non-null     int64
#  9   End month                           17 non-null     int64
#  10  End year                            17 non-null     int64
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df134.isnull().sum(), 100 * df134.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                     count           %
# Indicator.                              0    0.000000
# Reference 3                             0    0.000000
# Reference no# 3                         0    0.000000
# Reference 2                             0    0.000000
# Reference no# 2                         0    0.000000
# Link to reference 1                     0    0.000000
# Reference 1                             0    0.000000
# Reference no# 1                         0    0.000000
# Season                                  0    0.000000
# Survey methodology                      0    0.000000
# Indicator comments                      0    0.000000
# Method of analysis                      0    0.000000
# Fasting                                 0    0.000000
# Sample type                             0    0.000000
# Sample collection method                0    0.000000
# SurveyId                                0    0.000000
# ...

# %%
df134.Country.unique()
# Out:
# array(['Austria', 'France'], dtype=object)

# %%
df134['Begin year'].unique()
# Out:
# array([2010, 1994])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df135.info()
df135.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 51 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Indicator.                   107 non-null    object
#  1   CountryCode                  107 non-null    object
#  2   Country                      107 non-null    object
#  3   Representativeness.          107 non-null    object
#  4   Representativeness name      0 non-null      float64
#  5   Area covered                 107 non-null    object
#  6   Date                         107 non-null    int64
#  7   Begin month                  107 non-null    int64
#  8   Begin year                   107 non-null    int64
#  9   End month                    107 non-null    int64
#  10  End year                     107 non-null    int64
#  11  Population                   107 non-null    object
#  12  Gender                       107 non-null    object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df135.isnull().sum(), 100 * df135.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                              count           %
# Indicator.                       0    0.000000
# Reference 1                      0    0.000000
# Reference no# 1                  0    0.000000
# Season                           0    0.000000
# Survey methodology               0    0.000000
# Indicator comments               0    0.000000
# Method of analysis               0    0.000000
# Fasting                          0    0.000000
# Sample type                      0    0.000000
# Sample collection method         0    0.000000
# SurveyId                         0    0.000000
# Age from                         0    0.000000
# Age unit                         0    0.000000
# Survey status                    0    0.000000
# Population                       0    0.000000
# CountryCode                      0    0.000000
# Country                          0    0.000000
# Representativeness.              0    0.000000
# Area covered                     0    0.000000
# ...

# %%
df135.Country.unique()
# Out:
# array(['Australia', 'Austria', 'Canada', 'Chile', 'Costa Rica', 'Ecuador',
#        'France', 'United Kingdom of Great Britain and Northern',
#        'Ireland'], dtype=object)

# %%
df135['Begin year'].unique()
# Out:
# array([2011, 2010, 2007, 2009, 2008, 2012, 2006, 1994, 2000])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Prevalence of deficiency", "Mean", "Deficiency cut-off", "Median", "Prevalence of insufficiency", "Insufficiency cut-off", "U95CI", "L95CI"]
df135=df135[labels]

# %%
df135.shape
df135.head(15)
# Out:
#      Indicator.    Country  Date   Population  Gender Indicator unit  \
# 0   Vitamin B12  Australia  2012  Adolescents     All         pmol/L
# 1   Vitamin B12  Australia  2012       Adults     All         pmol/L
# 2   Vitamin B12  Australia  2012       Adults     All         pmol/L
# 3   Vitamin B12  Australia  2012       Adults     All         pmol/L
# 4   Vitamin B12  Australia  2012       Adults     All         pmol/L
# 5   Vitamin B12  Australia  2012       Adults     All         pmol/L
# 6   Vitamin B12  Australia  2012       Adults     All         pmol/L
# 7   Vitamin B12  Australia  2012       Adults  Female         pmol/L
# 8   Vitamin B12  Australia  2012      Elderly     All         pmol/L
# 9   Vitamin B12  Australia  2012      Elderly     All         pmol/L
# 10  Vitamin B12  Australia  2012          Men    Male         pmol/L
# 11  Vitamin B12    Austria  2012  Adolescents  Female         pmol/L
# 12  Vitamin B12    Austria  2012  Adolescents  Female         pmol/L
# ...

# %%
(df135["Country"] + ", " + df135["Population"]).value_counts()
# Out:
# Ecuador, Adults                                          12
# United Kingdom of Great Britain and Northern, Elderly     9
# Ireland, Adults                                           8
# Chile, Elderly                                            7
# Australia, Adults                                         7
# Canada, Elderly                                           6
# Ecuador, Adolescents                                      6
# Costa Rica, Elderly                                       6
# United Kingdom of Great Britain and Northern, Men         5
# Canada, Adolescents                                       4
# Costa Rica, Men                                           4
# Austria, Men                                              4
# Austria, Adolescents                                      4
# Costa Rica, Women                                         4
# Canada, Adults                                            4
# France, Adults                                            3
# ...

# %%
df135.Country.value_counts()
# Out:
# Ecuador                                         18
# Canada                                          17
# Costa Rica                                      14
# United Kingdom of Great Britain and Northern    14
# Austria                                         12
# Ireland                                         11
# Australia                                       11
# Chile                                            7
# France                                           3
# Name: Country, dtype: int64

# %%
df136.info()
df136.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 51 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Indicator.                        37 non-null     object
#  1   CountryCode                       37 non-null     object
#  2   Country                           37 non-null     object
#  3   Representativeness.               37 non-null     object
#  4   Representativeness name           0 non-null      float64
#  5   Area covered                      37 non-null     object
#  6   Date                              37 non-null     int64
#  7   Begin month                       37 non-null     int64
#  8   Begin year                        37 non-null     int64
#  9   End month                         37 non-null     int64
#  10  End year                          37 non-null     int64
#  11  Population                        37 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df136.isnull().sum(), 100 * df136.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                   count           %
# Indicator.                            0    0.000000
# Link to reference 1                   0    0.000000
# Reference 1                           0    0.000000
# Reference no# 1                       0    0.000000
# Season                                0    0.000000
# Survey methodology                    0    0.000000
# Indicator comments                    0    0.000000
# Method of analysis                    0    0.000000
# Fasting                               0    0.000000
# Sample type                           0    0.000000
# Sample collection method              0    0.000000
# SurveyId                              0    0.000000
# Age from                              0    0.000000
# Survey status                         0    0.000000
# Gender                                0    0.000000
# CountryCode                           0    0.000000
# Country                               0    0.000000
# ...

# %%
df136.Country.unique()
# Out:
# array(['Austria', 'France',
#        'United Kingdom of Great Britain and Northern'], dtype=object)

# %%
df136['Begin year'].unique()
# Out:
# array([2010, 1994, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df137.info()
df137.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 52 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Indicator.                         35 non-null     object
#  1   CountryCode                        35 non-null     object
#  2   Country                            35 non-null     object
#  3   Representativeness.                35 non-null     object
#  4   Representativeness name            0 non-null      float64
#  5   Area covered                       35 non-null     object
#  6   Date                               35 non-null     int64
#  7   Begin month                        35 non-null     int64
#  8   Begin year                         35 non-null     int64
#  9   End month                          35 non-null     int64
#  10  End year                           35 non-null     int64
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df137.isnull().sum(), 100 * df137.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                    count           %
# Indicator.                             0    0.000000
# Link to reference 1                    0    0.000000
# Reference 1                            0    0.000000
# Reference no# 1                        0    0.000000
# Season                                 0    0.000000
# Survey methodology                     0    0.000000
# Data adjusted for                      0    0.000000
# Method of analysis                     0    0.000000
# Fasting                                0    0.000000
# Sample type                            0    0.000000
# Sample collection method               0    0.000000
# SurveyId                               0    0.000000
# Age from                               0    0.000000
# Survey status                          0    0.000000
# Gender                                 0    0.000000
# CountryCode                            0    0.000000
# Country                                0    0.000000
# ...

# %%
df137.Country.unique()
# Out:
# array(['Austria', 'France',
#        'United Kingdom of Great Britain and Northern'], dtype=object)

# %%
df137['Begin year'].unique()
# Out:
# array([2010, 1994, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df138.info()
df138.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 50 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Indicator.                         24 non-null     object
#  1   CountryCode                        24 non-null     object
#  2   Country                            24 non-null     object
#  3   Representativeness.                24 non-null     object
#  4   Representativeness name            0 non-null      float64
#  5   Area covered                       24 non-null     object
#  6   Date                               24 non-null     int64
#  7   Begin month                        24 non-null     int64
#  8   Begin year                         24 non-null     int64
#  9   End month                          24 non-null     int64
#  10  End year                           24 non-null     int64
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df138.isnull().sum(), 100 * df138.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                                    count           %
# Indicator.                             0    0.000000
# Sample collection method               0    0.000000
# Sample type                            0    0.000000
# Fasting                                0    0.000000
# Method of analysis                     0    0.000000
# Data adjusted for                      0    0.000000
# Reference no# 1                        0    0.000000
# Season                                 0    0.000000
# Mean                                   0    0.000000
# Indicator unit                         0    0.000000
# Indicator comments                     0    0.000000
# Age from                               0    0.000000
# Reference 1                            0    0.000000
# Age unit                               0    0.000000
# Population                             0    0.000000
# End year                               0    0.000000
# End month                              0    0.000000
# ...

# %%
df138.Country.unique()
# Out:
# array(['Austria', 'United Kingdom of Great Britain and Northern'],
#       dtype=object)

# %%
df138['Begin year'].unique()
# Out:
# array([2010, 1994, 2000])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df139.info()
df139.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 54 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                21 non-null     object
#  1   CountryCode               21 non-null     object
#  2   Country                   21 non-null     object
#  3   Representativeness.       21 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              21 non-null     object
#  6   Date                      21 non-null     int64
#  7   Begin month               21 non-null     int64
#  8   Begin year                21 non-null     int64
#  9   End month                 21 non-null     int64
#  10  End year                  21 non-null     int64
#  11  Population                21 non-null     object
#  12  Gender                    21 non-null     object
#  13  Age unit                  21 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df139.isnull().sum(), 100 * df139.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Season                        0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Data adjusted for             0    0.000000
# Method of analysis            0    0.000000
# Sample collection method      0    0.000000
# SurveyId                      0    0.000000
# Age from                      0    0.000000
# Age unit                      0    0.000000
# Survey status                 0    0.000000
# Population                    0    0.000000
# CountryCode                   0    0.000000
# Country                       0    0.000000
# Representativeness.           0    0.000000
# Area covered                  0    0.000000
# Date                          0    0.000000
# Begin month                   0    0.000000
# ...

# %%
df139.Country.unique()
# Out:
# array(['Nepal', 'Cameroon', 'Armenia', "Lao People's Democratic Republic",
#        'Thailand'], dtype=object)

# %%
df139['Begin year'].unique()
# Out:
# array([2016, 2004, 2000, 1995])

# %% [markdown]
# Another indicator with too little data to use for this project.

# %%
df140.info()
df140.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Indicator.                76 non-null     object
#  1   CountryCode               76 non-null     object
#  2   Country                   76 non-null     object
#  3   Representativeness.       76 non-null     object
#  4   Representativeness name   0 non-null      float64
#  5   Area covered              76 non-null     object
#  6   Date                      76 non-null     int64
#  7   Begin month               69 non-null     float64
#  8   Begin year                69 non-null     float64
#  9   End month                 69 non-null     float64
#  10  End year                  76 non-null     int64
#  11  Population                76 non-null     object
#  12  Gender                    76 non-null     object
# ...

# %% [markdown]
# Checking for missing values:

# %%
missing = pd.concat([df140.isnull().sum(), 100 * df140.isnull().mean()], axis=1)
missing.columns=['count','%']
missing.sort_values(by='count',ascending=True)
# Out:
#                           count           %
# Indicator.                    0    0.000000
# Reference 1                   0    0.000000
# Reference no# 1               0    0.000000
# Season                        0    0.000000
# Survey methodology            0    0.000000
# Indicator comments            0    0.000000
# Data adjusted for             0    0.000000
# Method of analysis            0    0.000000
# Fasting                       0    0.000000
# Sample type                   0    0.000000
# Sample collection method      0    0.000000
# SurveyId                      0    0.000000
# Age from                      0    0.000000
# Survey status                 0    0.000000
# Gender                        0    0.000000
# CountryCode                   0    0.000000
# Country                       0    0.000000
# Representativeness.           0    0.000000
# Area covered                  0    0.000000
# Age unit                      0    0.000000
# ...

# %%
df140.Country.unique()
# Out:
# array(['Austria', 'Ecuador',
#        'United Kingdom of Great Britain and Northern', 'Kenya', 'Kuwait',
#        'Malawi', 'New Zealand', 'Philippines'], dtype=object)

# %%
df140['Begin year'].unique()
# Out:
# array([2010., 2012., 1994., 1999., 2011.,   nan, 2015., 2002., 2008.])

# %%
labels=["Indicator.", "Country", "Date", "Population", "Gender", "Indicator unit", "Prevalence of deficiency", "Mean", "Deficiency cut-off", "Median", "U95CI", "L95CI"]
df140=df140[labels]

# %%
df140.shape
df140.head(15)
# Out:
#                 Indicator.  Country  Date   Population  Gender Indicator unit  \
# 0   Zinc (plasma or serum)  Austria  2012  Adolescents  Female         µmol/L
# 1   Zinc (plasma or serum)  Austria  2012  Adolescents  Female         µmol/L
# 2   Zinc (plasma or serum)  Austria  2012  Adolescents    Male         µmol/L
# 3   Zinc (plasma or serum)  Austria  2012  Adolescents    Male         µmol/L
# 4   Zinc (plasma or serum)  Austria  2012      Elderly     All         µmol/L
# 5   Zinc (plasma or serum)  Austria  2012      Elderly  Female         µmol/L
# 6   Zinc (plasma or serum)  Austria  2012      Elderly    Male         µmol/L
# 7   Zinc (plasma or serum)  Austria  2012          Men    Male         µmol/L
# 8   Zinc (plasma or serum)  Austria  2012          Men    Male         µmol/L
# 9   Zinc (plasma or serum)  Austria  2012          Men    Male         µmol/L
# 10  Zinc (plasma or serum)  Austria  2012          Men    Male         µmol/L
# ...

# %%
(df140["Country"] + ", " + df140["Population"]).value_counts()
# Out:
# Philippines, Elderly                                     9
# Ecuador, Adolescents                                     9
# United Kingdom of Great Britain and Northern, Elderly    9
# Philippines, Adults                                      6
# Philippines, Men                                         5
# Malawi, Men                                              5
# Kuwait, Men                                              4
# Kenya, Men                                               4
# Austria, Adolescents                                     4
# Austria, Men                                             4
# Austria, Elderly                                         3
# Malawi, Adolescents                                      3
# Philippines, Adolescents                                 3
# Austria, Women                                           2
# Kuwait, Elderly                                          2
# New Zealand, Adolescents                                 2
# ...

# %%
df140.Country.value_counts()
# Out:
# Philippines                                     24
# Austria                                         13
# Ecuador                                          9
# United Kingdom of Great Britain and Northern     9
# Malawi                                           8
# Kuwait                                           7
# Kenya                                            4
# New Zealand                                      2
# Name: Country, dtype: int64

# %% [markdown]
# ### Micronutrient Status Data Availability Summary
#
# Indicators with data for more than five countries:
# <br>df114 25-Hydroxyvitamin D
# <br>df121 ferritin
# <br>df122 folate (plasma or serum)
# <br>df123 folate (red blood cell)
# <br>df125 haemoglobin
# <br>df127 iodine
# <br>df129 iron-deficiency anaemia
# <br>df135 vitamin B12
# <br>df140 zinc (plasma or serum)
#
# Indicators with data for more than three years:
# <br>df114 25-Hydroxyvitamin D
# <br>df121 ferritin
# <br>df122 folate (plasma or serum)
# <br>df123 folate (red blood cell)
# <br>df125 haemoglobin
# <br>df127 iodine
# <br>df129 iron-deficiency anaemia
# <br>df131 mean corpuscular volume (MCV)
# <br>df132 retinol binding protein
# <br>df135 vitamin B12
# <br>df139 xerophthalmia
# <br>df140 zinc (plasma or serum)
#
# Indicators with data for more than five countries and more than three years:
# <br>df114 25-Hydroxyvitamin D
# <br>df121 ferritin
# <br>df122 folate (plasma or serum)
# <br>df123 folate (red blood cell)
# <br>df125 haemoglobin
# <br>df127 iodine
# <br>df129 iron-deficiency anaemia
# <br>df135 vitamin B12
# <br>df140 zinc (plasma or serum)
#
# Upon closer examination of the above nine indicators, the information is not complete enough to use except potentially in the case of haemoglobin. For example, some indicators will have information for one subpopulation of a country (e.g. Men or Elderly) but not others (e.g. Women, Adolescents). As such, micronutrient status indicators will not be used.
